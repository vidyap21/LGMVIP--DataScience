# %%
 
    VIDYA PAYGUDE
    ---------------------------------------------------------------------------
    
   Data Science Intern at LetsGrowMore Virtual Internship Program (APRIL-2022)
    
   INTERMEDIATE LEVEL TASK 6 - Prediction using Decision Tree  Algorithm

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from sklearn import tree

# %%
data = datasets.load_iris()
df = pd.DataFrame(data.data,columns=data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# Checking Dimension and its length
df.shape
# Out:
# (150, 5)

# %%
#checking for null values
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
#showing only target data[Dependent variable]
print(df['target'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
sb.countplot(x = 'target', data=df)
plt.show()

# %%
#spliting data
fc = [x for x in df.columns if x!="target"]
x = df[fc]
y = df["target"]
X_train ,X_test,Y_train,Y_test = train_test_split(x,y,random_state=100,test_size=0.30)

# %%
#dispaly data
print("X_Train:",X_train.shape)
print("X_Test:",X_test.shape)
print("Y_Train:",Y_train.shape)
print("Y_Test:",Y_test.shape)
# Out:
# X_Train: (105, 4)
# X_Test: (45, 4)
# Y_Train: (105,)
# Y_Test: (45,)

# %%
# Model Creation
classifier = DecisionTreeClassifier()

# Model Training
classifier.fit(X_train, Y_train)

# Predicting
Y_pred = classifier.predict(X_test)

# %%
# Comparing Actual and Predicted
newdata = pd.DataFrame({"Actual":Y_test,"Predicted":Y_pred})
newdata.head(10)
# Out:
#      Actual  Predicted
# 128       2          2
# 11        0          0
# 118       2          2
# 15        0          0
# 123       2          2
# 135       2          2
# 32        0          0
# 1         0          0
# 116       2          2
# 45        0          0

# %%
# Testing the accuracy of model
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9555555555555556

# %%
# plotting the classifier tree
fn = ["Sepal length", "Sepal width", "Petal length", "Petal width"]
cn = ["Setosa","Versicolor","Virginica"]
plt.figure(figsize=(10,10))
plot_tree(classifier,feature_names=fn,class_names=cn,filled=True)
# Out:
# [Text(223.2, 489.24, 'Petal width <= 0.8\ngini = 0.664\nsamples = 105\nvalue = [34, 39, 32]\nclass = Versicolor'),
#  Text(167.39999999999998, 380.52000000000004, 'gini = 0.0\nsamples = 34\nvalue = [34, 0, 0]\nclass = Setosa'),
#  Text(279.0, 380.52000000000004, 'Petal width <= 1.65\ngini = 0.495\nsamples = 71\nvalue = [0, 39, 32]\nclass = Versicolor'),
#  Text(111.6, 271.8, 'Petal length <= 5.0\ngini = 0.136\nsamples = 41\nvalue = [0, 38, 3]\nclass = Versicolor'),
#  Text(55.8, 163.08000000000004, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]\nclass = Versicolor'),
#  Text(167.39999999999998, 163.08000000000004, 'Sepal length <= 6.05\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = Virginica'),
#  Text(111.6, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(223.2, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Virginica'),
#  Text(446.4, 271.8, 'Petal length <= 4.85\ngini = 0.064\nsamples = 30\nvalue = [0, 1, 29]\nclass = Virginica'),
#  Text(390.59999999999997, 163.08000000000004, 'Sepal width <= 3.1\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]\nclass = Virginica'),
#  Text(334.79999999999995, 54.360000000000014, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = Virginica'),
#  Text(446.4, 54.360000000000014, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = Versicolor'),
#  Text(502.2, 163.08000000000004, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26]\nclass = Virginica')]

# %%
# Final Result for all x and y
classifierX = DecisionTreeClassifier().fit(x,y)
plt.figure(figsize=(15,15))
tree = plot_tree(classifierX,feature_names=fn,class_names=cn,filled=True)
